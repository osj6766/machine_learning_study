# %%
import math, copy
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
from lab_utils_uni import plt_house_x, plt_contour_wgrad, plt_divergence, plt_gradients

# %%
#Load our data set
x_train = np.array([1,2])
y_train = np.array([300, 500])

# %%
def compute_cost(x,y,w,b) : 

    m = x.shape[0]
    cost = 0

    for i in range(m):
        f_wb = w*x[i] + b
        cost = cost + (f_wb - y[i])**2
    total_cost = cost/(2*m)

    return total_cost

# %%
def compute_gradient(x,y,w,b) :

    m = x.shape[0]
    dj_dw = 0
    dj_db = 0

    for i in range[m]:
        f_wb = w*x[i] + b
        dj_dw_i = (f_wb - y[i])*x[i]
        dj_db_i = (f_wb - y[i])
        dj_dw += dj_dw_i
        dj_db += dj_db_i
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    
    return dj_dw, dj_db

# %%
plt_gradients(x_train, y_train, compute_cost, compute_gradient)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt_gradients(x_train, y_train, compute_cost, compute_gradient)
#       2 plt.show()
#
# File ~\Documents\GitHub\machine_learning_study\andrew ng code myself\lab_utils_uni.py:376, in plt_gradients(x_train, y_train, f_compute_cost, f_compute_gradient)
#     374 for tmp_w in [100,200,300]:
#     375     fix_b = 100
# --> 376     dj_dw,dj_db = f_compute_gradient(x_train, y_train, tmp_w, fix_b )
#     377     j = f_compute_cost(x_train, y_train, tmp_w, fix_b)
#     378     add_line(dj_dw, tmp_w, j, 30, ax[0])
#
# Cell In[4], line 7, in compute_gradient(x, y, w, b)
#       4 dj_dw = 0
#       5 dj_db = 0
# ----> 7 for i in range[m]:
#       8     f_wb = w*x[i] + b
#       9     dj_dw_i = (f_wb - y[i])*x[i]
#
# TypeError: 'type' object is not subscriptable
